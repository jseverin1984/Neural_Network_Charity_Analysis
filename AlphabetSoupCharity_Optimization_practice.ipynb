# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# ...

# %%
application_df.loc[application_df['ASK_AMT'] > 2000000000]
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 21633               T3       Independent          C1000     Heathcare
# 24795               T3       Independent          C2000  Preservation
# 24947               T3       Independent          C1000     Heathcare
# 31337               T3  CompanySponsored          C1000  Preservation
# 33175               T3       Independent          C1000     Heathcare
# 33678               T3       Independent          C1200     Heathcare
# 34222               T3       Independent          C2000  Preservation
#
#        ORGANIZATION SPECIAL_CONSIDERATIONS     ASK_AMT  IS_SUCCESSFUL
# 21633         Trust                      N  2264109450              0
# 24795         Trust                      N  4653011914              0
# 24947         Trust                      N  2310256039              1
# 31337         Trust                      N  3391919220              1
# ...

# %%
application_df.describe()
# Out:
#                 EIN        STATUS       ASK_AMT  IS_SUCCESSFUL
# count  3.429900e+04  34299.000000  3.429900e+04   34299.000000
# mean   5.191852e+08      0.999854  2.769199e+06       0.532406
# std    2.451472e+08      0.012073  8.713045e+07       0.498956
# min    1.052060e+07      0.000000  5.000000e+03       0.000000
# 25%    2.748482e+08      1.000000  5.000000e+03       0.000000
# 50%    4.656317e+08      1.000000  5.000000e+03       1.000000
# 75%    7.526117e+08      1.000000  7.742000e+03       1.000000
# max    9.960869e+08      1.000000  8.597806e+09       1.000000

# %%
application_df['INCOME_AMT'].value_counts(normalize=True)
# Out:
# 0                0.711041
# 25000-99999      0.109245
# 100000-499999    0.098370
# 1M-5M            0.027843
# 1-9999           0.021225
# 10000-24999      0.015831
# 10M-50M          0.006997
# 5M-10M           0.005394
# 50M+             0.004053
# Name: INCOME_AMT, dtype: float64

# %%
application_df['STATUS'].value_counts()
# Out:
# 1    34294
# 0        5
# Name: STATUS, dtype: int64

# %%
application_df['SPECIAL_CONSIDERATIONS'].value_counts()
# Out:
# N    34272
# Y       27
# Name: SPECIAL_CONSIDERATIONS, dtype: int64

# %%
application_df['ORGANIZATION'].value_counts()
# Out:
# Trust           23515
# Association     10255
# Co-operative      486
# Corporation        43
# Name: ORGANIZATION, dtype: int64

# %%
application_df['USE_CASE'].value_counts()
# Out:
# Preservation     28095
# ProductDev        5671
# CommunityServ      384
# Heathcare          146
# Other                3
# Name: USE_CASE, dtype: int64

# %%
# dropping the row INCOME_AMT because over 71 percent of the column has a zero value, which would skew my data set
# dropping STATUS because over 99% of the column is 1, making the column irrelevent. I think, maybe. I'm doing it anyways
# also dropping EIN and NAME
application_df.drop(columns=['EIN', 'NAME', 'INCOME_AMT', 'STATUS'], inplace=True)
